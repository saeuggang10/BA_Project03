# %%
import numpy as np
import pandas as pd
import re
import time
from tqdm.notebook import tqdm

# 지도 + 시각화
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc #한글지원
import platform
import seaborn as sns
plt.rc("font",family='Malgun Gothic') #한글_글꼴
plt.rcParams['axes.unicode_minus'] = False #음수표시

import folium

# 거리계산
from haversine import haversine #패키지 설치필요

# %%
### 지도시각화
class Mapping:

    def __init__(self, s_lat=37.758206, s_lng=128.806648):
        file_path = './data/'
        self.return_map = folium.Map(location=[s_lat, s_lng],
                                     tiles='openstreetmap',
                                     zoom_start=50)
        self.sleep = pd.read_excel(file_path + '졸음쉼터+편의시설.xlsx')
        self.rest = pd.read_csv(file_path + '휴게소정보_20210809.csv',
                                encoding='euc-kr')
        self.danger = pd.read_csv(file_path + 'danger.csv')
        self.tunnel = pd.read_excel(file_path + '터널_위치_수정.xlsx')
        self.crush_bound_cnt = pd.read_excel(file_path + '졸음쉼터_주변사고.xlsx')
        self.rest = self.rest.iloc[:, :-4]
        for val in self.rest.columns[12:]:
            self.rest = self.rest.rename(columns={val: val[:-2]})  #변수명 변경
        self.icon_lis = list('🅿🪛⛽⛽🔌🚌🛏🚻💊🚼🍴😋')
        self.icon_lis2 = list('🅿🪑⛱💪🍴⛟🍹')

    ### 휴게소 표시
    def rest_map(self):
        for i in range(0, len(self.rest)):
            lat = self.rest.loc[i, '위도']  #위도
            lng = self.rest.loc[i, '경도']  #경도

            str_pop = ''
            for j, icon in zip(range(11, len(self.rest.columns)),
                               self.icon_lis):
                if j == len(self.rest.columns) - 1:
                    str_pop += '<b>{}</b> | {}'.format(
                        self.rest.columns[j] + icon, self.rest.iloc[i, j])
                else:
                    str_pop += '<b>{}</b> | {} <br/>'.format(
                        self.rest.columns[j] + icon, self.rest.iloc[i, j])

            popup = folium.Popup(str_pop, max_width=200)

            folium.Marker(location=[lat, lng],
                          tooltip=self.rest.loc[i, '휴게소명'],
                          popup=popup,
                          icon=folium.Icon(color='blue',
                                           icon='utensils',
                                           prefix='fa')).add_to(
                                               self.return_map)  #마커 표시
        return self.return_map

    ### 졸음쉼터 표시
    def sleep_map(self):
        _, fc_50, fc_75 = np.percentile(self.crush_bound_cnt['cnt'], [25, 50, 75])
        for i in range(0, len(self.sleep)):
            lat = self.sleep.loc[i, '위도']  #위도
            lng = self.sleep.loc[i, '경도']  #경도

            str_pop = ''
            for j, icon in zip(range(4, len(self.sleep.columns)),
                               self.icon_lis2):
                if j == len(self.sleep.columns) - 1:
                    str_pop += '<b>{}</b> | {}'.format(
                        self.sleep.columns[j] + icon, self.sleep.iloc[i, j])
                else:
                    str_pop += '<b>{}</b> | {} <br/>'.format(
                        self.sleep.columns[j] + icon, self.sleep.iloc[i, j])

            popup = folium.Popup(str_pop, max_width=200)
            
            if self.sleep.loc[i,'졸음쉼터명'] in self.crush_bound_cnt['졸음쉼터명'].unique():
                temp = self.crush_bound_cnt[self.crush_bound_cnt['졸음쉼터명'] == self.sleep.loc[i,'졸음쉼터명']]['cnt'].values[0]
                if temp>=fc_75:
                    f_c = 'red' #주변 사고 발생률이 상위 25%인 졸음쉼터는 빨간색 마커
                elif temp>=fc_50:
                    f_c = 'orange' #주변 사고 발생률이 상위 50%인 졸음쉼터는 오렌지색 마커
                else:
                     f_c = 'green'
            else:
                f_c = 'cadetblue'

            folium.Marker(location=[lat, lng],
                          tooltip=self.sleep.loc[i, '졸음쉼터명'],
                          popup=popup,
                          icon=folium.Icon(color=f_c,
                                           icon='bed',
                                           prefix='fa')).add_to(
                                               self.return_map)
        return self.return_map

    ### 사고다발지역 표시
    def crush_circle(self):
        for i in range(0, len(self.danger)):
            if self.danger['danger_rank'][i] == 3:
                f_c = 'orange'
            else:
                f_c = 'red'

            folium.Circle(
                location=[self.danger.iloc[i, -2], self.danger.iloc[i, -1]],
                radius=100,
                color=f_c,
                fill_color=f_c).add_to(self.return_map)
        return self.return_map

    ### 터널위치 표시
    def tunnel_poly(self):
        for i in self.tunnel.index:
            folium.PolyLine(
                locations=[[self.tunnel.iloc[i, 4], self.tunnel.iloc[i, 5]],
                           [self.tunnel.iloc[i, 6], self.tunnel.iloc[i, 7]]],
                color='gray',
                tooltip=self.tunnel.iloc[i, 0],
                width=3).add_to(self.return_map)
        return self.return_map

# %% [markdown]
# # class test

# %%
a = Mapping()
a.sleep_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8776dc5d977696b55e8ba1547134460 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8776dc5d977696b55e8ba1547134460&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8776dc5d977696b55e8ba1547134460 = L.map(
#                 &quot;map_d8776dc5d977696b55e8ba1547134460&quot;,
#                 {
#                     center: [37.758206, 128.806648],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 50,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6fab7ae0791e8f31996fd154e4325822 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d8776dc5d977696b55e8ba1547134460);
#
#
#             var marker_d65c0eb12b9c80b147f6b29d570749fe = L.marker(
#                 [37.1690741, 127.6265365],
#                 {}
#             ).addTo(map_d8776dc5d977696b55e8ba1547134460);
#
#
#             var icon_e979d90b70955ccab6fb6a7faa68f02d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bed&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d65c0eb12b9c80b147f6b29d570749fe.setIcon(icon_e979d90b70955ccab6fb6a7faa68f02d);
#
#
#         var popup_e8f389d63866e2ae877f3e64901eb23f = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_ceb92947c0c9213f0bd5366c1f26e4de = $(`&lt;div id=&quot;html_ceb92947c0c9213f0bd5366c1f26e4de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;주차면수🅿&lt;/b&gt; | 17 &lt;br/&gt;&lt;b&gt;벤치 및 파고라 유무🪑&lt;/b&gt; | O &lt;br/&gt;&lt;b&gt;차량용 차양시설 유무⛱&lt;/b&gt; | O &lt;br/&gt;&lt;b&gt;운동시설 유무💪&lt;/b&gt; | X &lt;br/&gt;&lt;b&gt;매점 유무🍴&lt;/b&gt; | X &lt;br/&gt;&lt;b&gt;푸드트럭 유무⛟&lt;/b&gt; | O &lt;br/&gt;&lt;b&gt;자판기 유무🍹&lt;/b&gt; | X&lt;/div&gt;`)[0];
#                 popup_e8f389d63866e2ae877f3e64901eb23f.setContent(html_ceb92947c0c9213f0bd5366c1f26e4de);
#
#
#
#         marker_d65c0eb12b9c80b147f6b29d570749fe.bindPopup(popup_e8f389d63866e2ae877f3e64901eb23f)
#         ;
#
#
#
#
#             marker_d65c0eb12b9c80b147f6b29d570749fe.bindTooltip(
#                 `&lt;div&gt;
#                      가남
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bd2e6d80958d5c998f2b040b928d8f80 = L.marker(
#                 [36.63471618, 126.5531285],
#                 {}
#             ).addTo(map_d8776dc5d977696b55e8ba1547134460);
#
#
#             var icon_30423990a52bc9af4f0a9650464645d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bed&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_bd2e6d80958d5c998f2b040b928d8f80.setIcon(icon_30423990a52bc9af4f0a9650464645d0);
#
#
#         var popup_f35775c3f78aa1df61d134f55c371614 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_8b677503a9dea6d91bcd44d6e70faf16 = $(`&lt;div id=&quot;html_8b677503a9dea6d91bcd44d6e70faf16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;주차면수🅿&lt;/b&gt; | 6 &lt;br/&gt;&lt;b&gt;벤치 및 파고라 유무🪑&lt;/b&gt; | X &lt;br/&gt;&lt;b&gt;차량용 차양시설 유무⛱&lt;/b&gt; | X &lt;br/&gt;&lt;b&gt;운동시설 유무💪&lt;/b&gt; | O &lt;br/&gt;&lt;b&gt;매점 유무🍴&lt;/b&gt; | X &lt;br/&gt;&lt;b&gt;푸드트럭 유무⛟&lt;/b&gt; | X &lt;br/&gt;&lt;b&gt;자판기 유무🍹&lt;/b&gt; | X&lt;/div&gt;`)[0];
#                 popup_f35775c3f78aa1df61d134f55c371614.setContent(html_8b677503a9dea6d91bcd44d6e70faf16);
#
#
#
#         marker_bd2e6d80958d5c998f2b040b928d8f80.bindPopup(popup_f35775c3f78aa1df61d134f55c371614)
#         ;
#
#
#
#
#             marker_bd2e6d80958d5c998f2b040b928d8f80.bindTooltip(
#                 `&lt;div&gt;
#                      갈산
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e44d77fde613bea3004e26d246ed1d65 = L.marker(
#                 [34.68656192, 126.7740237],
#                 {}
#             ).addTo(map_d8776dc5d977696b55e8ba1547134460);
#
#
#             var icon_1f31b261a9be07e1498f879c8752325b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;bed&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e44d77fde613bea3004e26d246ed1d65.setIcon(icon_1f31b261a9be07e1498f879c8752325b);

# %%
a = Mapping()
a.rest_map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3eacae4ca5226d15b29f884251afc616 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3eacae4ca5226d15b29f884251afc616&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3eacae4ca5226d15b29f884251afc616 = L.map(
#                 &quot;map_3eacae4ca5226d15b29f884251afc616&quot;,
#                 {
#                     center: [37.758206, 128.806648],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 50,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b23c73ba24e37d5b8e4cc1fd5c28ae3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3eacae4ca5226d15b29f884251afc616);
#
#
#             var marker_38a6b89cb38b0bb6a40992edd83bdfd1 = L.marker(
#                 [37.758206, 128.806648],
#                 {}
#             ).addTo(map_3eacae4ca5226d15b29f884251afc616);
#
#
#             var icon_81d9c777c4b3246e802eff49e328819b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;utensils&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_38a6b89cb38b0bb6a40992edd83bdfd1.setIcon(icon_81d9c777c4b3246e802eff49e328819b);
#
#
#         var popup_b9e0332026025a69f934f79e41dc8713 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_b068d80f5a8ce9439dbb469eabe3cdaa = $(`&lt;div id=&quot;html_b068d80f5a8ce9439dbb469eabe3cdaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;주차면수🅿&lt;/b&gt; | 252 &lt;br/&gt;&lt;b&gt;경정비가능🪛&lt;/b&gt; | N &lt;br/&gt;&lt;b&gt;주유소⛽&lt;/b&gt; | Y &lt;br/&gt;&lt;b&gt;LPG충전소⛽&lt;/b&gt; | Y &lt;br/&gt;&lt;b&gt;전기차충전소🔌&lt;/b&gt; | Y &lt;br/&gt;&lt;b&gt;버스환승가능🚌&lt;/b&gt; | N &lt;br/&gt;&lt;b&gt;쉼터🛏&lt;/b&gt; | Y &lt;br/&gt;&lt;b&gt;화장실🚻&lt;/b&gt; | Y &lt;br/&gt;&lt;b&gt;약국💊&lt;/b&gt; | N &lt;br/&gt;&lt;b&gt;수유실🚼&lt;/b&gt; | Y &lt;br/&gt;&lt;b&gt;매점🍴&lt;/b&gt; | Y &lt;br/&gt;&lt;b&gt;음식점😋&lt;/b&gt; | Y&lt;/div&gt;`)[0];
#                 popup_b9e0332026025a69f934f79e41dc8713.setContent(html_b068d80f5a8ce9439dbb469eabe3cdaa);
#
#
#
#         marker_38a6b89cb38b0bb6a40992edd83bdfd1.bindPopup(popup_b9e0332026025a69f934f79e41dc8713)
#         ;
#
#
#
#
#             marker_38a6b89cb38b0bb6a40992edd83bdfd1.bindTooltip(
#                 `&lt;div&gt;
#                      강릉(강릉)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ad27579b7aa38a1f42e7094e160fa8bd = L.marker(
#                 [37.760275, 128.8053601],
#                 {}
#             ).addTo(map_3eacae4ca5226d15b29f884251afc616);
#
#
#             var icon_9dd0ca806831c09dfc4fbc174c48522e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;utensils&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ad27579b7aa38a1f42e7094e160fa8bd.setIcon(icon_9dd0ca806831c09dfc4fbc174c48522e);
#
#
#         var popup_6b28f3f002f385367dba302ad694e9ad = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_031d577dd6fb153930e33c4f47850fe2 = $(`&lt;div id=&quot;html_031d577dd6fb153930e33c4f47850fe2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;주차면수🅿&lt;/b&gt; | 279 &lt;br/&gt;&lt;b&gt;경정비가능🪛&lt;/b&gt; | N &lt;br/&gt;&lt;b&gt;주유소⛽&lt;/b&gt; | Y &lt;br/&gt;&lt;b&gt;LPG충전소⛽&lt;/b&gt; | Y &lt;br/&gt;&lt;b&gt;전기차충전소🔌&lt;/b&gt; | Y &lt;br/&gt;&lt;b&gt;버스환승가능🚌&lt;/b&gt; | N &lt;br/&gt;&lt;b&gt;쉼터🛏&lt;/b&gt; | Y &lt;br/&gt;&lt;b&gt;화장실🚻&lt;/b&gt; | Y &lt;br/&gt;&lt;b&gt;약국💊&lt;/b&gt; | N &lt;br/&gt;&lt;b&gt;수유실🚼&lt;/b&gt; | Y &lt;br/&gt;&lt;b&gt;매점🍴&lt;/b&gt; | Y &lt;br/&gt;&lt;b&gt;음식점😋&lt;/b&gt; | Y&lt;/div&gt;`)[0];
#                 popup_6b28f3f002f385367dba302ad694e9ad.setContent(html_031d577dd6fb153930e33c4f47850fe2);
#
#
#
#         marker_ad27579b7aa38a1f42e7094e160fa8bd.bindPopup(popup_6b28f3f002f385367dba302ad694e9ad)
#         ;
#
#
#
#
#             marker_ad27579b7aa38a1f42e7094e160fa8bd.bindTooltip(
#                 `&lt;div&gt;
#                      강릉(인천)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f8cdec65a9d8aa9b5104b8e812616ab7 = L.marker(
#                 [35.3657501, 127.105451],
#                 {}
#             ).addTo(map_3eacae4ca5226d15b29f884251afc616);
#
#
#             var icon_e09b8f69f21c304a1469c1a0389e1a1a = L.AwesomeMarkers.icon(
